# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanka-pandya/ML-Practicals/blob/main/aglo2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

data = [['milk', 'bread', 'egg'],
	['milk', 'bread'],
	['milk', 'bread', 'egg', 'banana'],
	['milk', 'banana']]
te = TransactionEncoder()
te_ary = te.fit_transform(data)
df = pd.DataFrame(te_ary, columns=te.columns_)

# Generate
frequent_itemsets = apriori(df, min_support=0.5, use_colnames=True)

# Generate
rules = association_rules(frequent_itemsets, metric='confidence', min_threshold=0.75)

# Print
for i in range(len(rules)):
    LHS = list(rules['antecedents'].iloc[i])
    RHS = list(rules['consequents'].iloc[i])
    support = rules['support'].iloc[i]
    confidence = rules['confidence'].iloc[i]
    #lift = rules['lift'].iloc[i]
    print(f"LHS: {LHS} -- RHS: {RHS}")
    print(f"Support: {support}")
    print(f"Confidence: {confidence}")
    #print(f"Lift: {lift}")
    print("---")
# Out:
# LHS: ['banana'] -- RHS: ['milk']
# Support: 0.5
# Confidence: 1.0
# ---
# LHS: ['egg'] -- RHS: ['bread']
# Support: 0.5
# Confidence: 1.0
# ---
# LHS: ['bread'] -- RHS: ['milk']
# Support: 0.75
# Confidence: 1.0
# ---
# LHS: ['milk'] -- RHS: ['bread']
# Support: 0.75
# Confidence: 0.75
# ---
# LHS: ['egg'] -- RHS: ['milk']
# Support: 0.5
# Confidence: 1.0
# ---
# LHS: ['egg', 'bread'] -- RHS: ['milk']
# Support: 0.5
# Confidence: 1.0
# ---
# LHS: ['egg', 'milk'] -- RHS: ['bread']
# Support: 0.5
# Confidence: 1.0
# ---
# LHS: ['egg'] -- RHS: ['bread', 'milk']
# Support: 0.5
# Confidence: 1.0
# ---
# /usr/local/lib/python3.12/dist-packages/mlxtend/frequent_patterns/association_rules.py:186: RuntimeWarning: invalid value encountered in divide
#   cert_metric = np.where(certainty_denom == 0, 0, certainty_num / certainty_denom)
# ...
